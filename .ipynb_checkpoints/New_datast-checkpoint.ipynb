# %% [markdown]
# # Final DataSet preperation
# - calll all dataset
# - marge by Patient ID which is MRN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import warnings
import os
import scipy

from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
import pandas as pd

# Load datasets
df1 = pd.read_csv('C:/Users/Daveee/Downloads/Diagnosis.csv')
df2 = pd.read_csv('C:/Users/Daveee/Downloads/Vital And Physical.csv')
df3 = pd.read_csv('C:/Users/Daveee/Downloads/Services.csv')
df4 = pd.read_csv('C:/Users/Daveee/Downloads/History.csv')
df5 = pd.read_csv('C:/Users/Daveee/Downloads/Prescription.csv')

# Ensure that all datasets have 150,939 rows, adjusting as needed
target_rows = 150939

def adjust_rows(df, target_rows):
    current_rows = len(df)
    if current_rows > target_rows:
        # Truncate rows if dataframe has more than 150,939 rows
        return df.iloc[:target_rows]
    elif current_rows < target_rows:
        # Pad with NaN values if dataframe has less than 150,939 rows
        padding = pd.DataFrame([[None] * len(df.columns)], columns=df.columns)
        padded_df = pd.concat([df, pd.concat([padding] * (target_rows - current_rows), ignore_index=True)], ignore_index=True)
        return padded_df
    return df

# Adjust rows for each dataframe
df2_adjusted = adjust_rows(df2[['Record', 'Value']], target_rows)  # Replace with actual column names
df3_adjusted = adjust_rows(df3[['Service', 'Price', 'Is Paid', 'Is Available']], target_rows)
df4_adjusted = adjust_rows(df4[['Record Type', 'Value']], target_rows)
df5_adjusted = adjust_rows(df5[['Record Type', 'Prescribed Item']], target_rows)

# Concatenate df1 with the selected columns from other dataframes
df_final = pd.concat([df1, df2_adjusted, df3_adjusted, df4_adjusted, df5_adjusted], axis=1)

# Save the final dataset to a new CSV file
df_final.to_csv('C:/Users/Daveee/Desktop/image caption model with app/Text Datasets/FilteredDataset.csv', index=False)

# %%
df_final
# Out:
#              MRN   Age     Sex Occupation  \
# 0       272161.0  50.0    Male        NaN
# 1       212951.0  62.0    Male        NaN
# 2       271933.0  45.0  Female        NaN
# 3       272501.0  26.0  Female        NaN
# 4       167838.0   3.0    Male        NaN
# ...          ...   ...     ...        ...
# 150934  181366.0   0.0    Male        NaN
# 150935  192533.0  55.0    Male        NaN
# 150936  195936.0  27.0  Female        NaN
# 150937  197688.0  37.0    Male        NaN
# 150938       NaN   NaN     NaN        NaN
#
#                                              Region             Zone  \
# 0       Southern Nations, Nationalities and Peoples           Gurage
# 1                                       Addis Ababa      Addis Ababa
# 2                                            Oromia  Oromia-Finfinne
# 3                                       Addis Ababa      Addis Ababa
# 4                                            Oromia  Oromia-Finfinne
# ...                                             ...              ...
# 150934                                  Addis Ababa      Addis Ababa
# 150935                                       Amhara      East Gojjam
# 150936                                  Addis Ababa      Addis Ababa
# 150937                                       Oromia            Jimma
# 150938                                          NaN              NaN
#
#                City       SubCity   Woreda Kebel  ...              Record  \
# 0           Welkite           NaN  Welkite   NaN  ...         Weight (kg)
# 1       Addis Ababa          Yeka        1   NaN  ...                  BP
# 2            BURAYU           NaN   BURAYU   NaN  ...         Weight (kg)
# 3       Addis Ababa        Lideta        3   NaN  ...                  BP
# 4              Metw         Metwe     Metw   NaN  ...         Weight (kg)
# ...             ...           ...      ...   ...  ...                 ...
# 150934  Addis Ababa        Lideta        3   NaN  ...  General Appearance
# 150935      Gozamer       Gozamer  Gozamre   NaN  ...                  BP
# 150936  Addis Ababa  Addis Ketema        6    33  ...         Weight (kg)
# 150937        Jimma         Jimma    Jimma   NaN  ...                 CNS
# 150938          NaN           NaN      NaN   NaN  ...         Weight (kg)
#
#          Value                                    Service  Price Is Paid  \
# 0           83                                 CT Abdomen  535.0       1
# 1       112/62  CT Abdomen Triphasic Scan (Liver / Renal)  535.0       1
# 2           92               CT Angiography with Contrast  800.0       1
# 3       120/91                                   CT Brain  535.0       1
# 4           40                             CT Elbow Joint  535.0       1
# ...        ...                                        ...    ...     ...
# 150934     CSL                                        CRP   80.0       1
# 150935  120/85                                        ELE  450.0       0
# 150936      99                                        RFT  100.0       0
# 150937   alert                   New Patient Registration  100.0       1
# 150938   14 kg               Patient Registration Renewal  100.0       1
#
#        Is Available Record Type  \
# 0                 1     HISTORY
# 1                 1     HISTORY
# 2                 1     HISTORY
# 3                 1     HISTORY
# 4                 1     HISTORY
# ...             ...         ...
# 150934            1     HISTORY
# 150935            0  MANAGEMENT
# 150936            0     HISTORY
# 150937            0     HISTORY
# 150938            0     HISTORY
#
#                                                     Value   Record Type  \
# 0       Known cardiac pt on follow up on atenolol 25mg...  Prescription
# 1                                        has no compliant  Prescription
# 2       c/c: BACK PAIN/01 month  45yrs old female pati...  Prescription
# 3            vitals: BP: 100/60      PR: 80 RR: 20 T: ATT  Prescription
# 4       known cardiac  pt on follow up  currently has ...  Prescription
# ...                                                   ...           ...
# 150934  P; cerebelar ataxia 2ry to ?primary progressiv...  Prescription
# 150935                           RTC after 01 and 2 weeks  Prescription
# 150936  p-post GDM, 4WK POST PARTUM INSULIN HOLDED FBS...  Prescription
# 150937  Warfarin 7.5mg po 6day/wk, 5mg 1day/wk for 01m...  Prescription
# 150938  p=RPGN of unclear cause, not biopsied, partial...  Prescription
#
#                                           Prescribed Item
# 0       {"Name":"paracetamol","Strength":"10mg","Presc...
# 1       {"PrescriptionType":"Supply","Name":"METRENDAZ...
# 2       {"PrescriptionType":"Supply","Name":"CEFTRIAXO...
# 3       {"PrescriptionType":"Supply","Name":"HEPARINE ...
# 4       {"PrescriptionType":"Supply","Name":"SYRINGE 1...
# ...                                                   ...
# 150934  {"PrescriptionType":"Supply","Name":"DEXAMETAS...
# 150935  {"PrescriptionType":"Supply","Name":"10cc syri...
# 150936  {"PrescriptionType":"Supply","Name":"glove","S...
# 150937  {"PrescriptionType":"Supply","Name":"NS","Stre...
# 150938  {"PrescriptionType":"Supply","Name":"ondasetro...
#
# [150939 rows x 26 columns]

# %% [markdown]
# ## filter out unit
# - Oncology',
# - 'Oncology Ward (D-8 Ward)',
# - 'Hematology',
# - 'Gynecology OPD'

# %%
df9 = pd.read_csv('C:/Users/Daveee/Desktop/image caption model with app/Text Datasets/FilteredDataset.csv')
# Define the list of units to filter
units_to_extract = ['Oncology', 'Oncology Ward (D-8 Ward)', 'Hematology', 'Gynecology OPD']

# Filter the dataframe where Unit is one of the specified values
filtered_df = df9[df9['Unit'].isin(units_to_extract)]

# Save the filtered data to a new CSV file (optional)
filtered_df.to_csv('C:/Users/Daveee/Desktop/image caption model with app/Text Datasets/FilteredDatasetDiagnosis.csv', index=False)

# Display the filtered dataframe
filtered_df
# Out:
# C:\Users\Daveee\AppData\Local\Temp\ipykernel_4416\4023202929.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df9 = pd.read_csv('C:/Users/Daveee/Desktop/image caption model with app/Text Datasets/FilteredDataset.csv')
#              MRN   Age     Sex Occupation  \
# 0       272161.0  50.0    Male        NaN
# 2       271933.0  45.0  Female        NaN
# 5       272272.0  51.0  Female        NaN
# 10      272380.0  72.0  Female        NaN
# 13      267125.0  60.0    Male        NaN
# ...          ...   ...     ...        ...
# 150925  193905.0  40.0  Female        NaN
# 150927  192271.0  45.0  Female        NaN
# 150928    1323.0  39.0  Female        NaN
# 150929   10222.0  21.0    Male        NaN
# 150930  160158.0  29.0  Female        NaN
#
#                                              Region             Zone  \
# 0       Southern Nations, Nationalities and Peoples           Gurage
# 2                                            Oromia  Oromia-Finfinne
# 5                                       Addis Ababa      Addis Ababa
# 10                                 Benshangul-Gumaz            Asosa
# 13      Southern Nations, Nationalities and Peoples           Gurage
# ...                                             ...              ...
# 150925                                       Oromia       East Shewa
# 150927                                  Addis Ababa      Addis Ababa
# 150928                                       Oromia  Oromia-Finfinne
# 150929                                          NaN              NaN
# 150930                                  Addis Ababa      Addis Ababa
#
#                    City  SubCity   Woreda Kebel  ...              Record  \
# 0               Welkite      NaN  Welkite   NaN  ...         Weight (kg)
# 2                BURAYU      NaN   BURAYU   NaN  ...         Weight (kg)
# 5           Addis Ababa     Yeka        1   NaN  ...                  BP
# 10                Asosa      NaN    Asosa   NaN  ...         Weight (kg)
# 13               GURAGE      NaN   ENDGJE   NaN  ...                  BP
# ...                 ...      ...      ...   ...  ...                 ...
# 150925            Adama    Adama    Adama   NaN  ...                 CVS
# 150927      Addis Ababa  Gullele        6   NaN  ...                  RR
# 150928  Oromia-Finfinne      NaN   sebeta   NaN  ...                SP°2
# 150929              NaN   KIRKOS      NaN   NaN  ...       Integumentary
# 150930      Addis Ababa    Kolfe        3   NaN  ...  General Appearance
#
#                                                     Value  \
# 0                                                      83
# 2                                                      92
# 5                                                   97/62
# 10                                                     78
# 13                                                  95/62
# ...                                                   ...
# 150925                                       unremarkable
# 150927                                                 18
# 150928                                                 96
# 150929  there are excoriation marks over the leg, the ...
# 150930                                       well looking
#
#                              Service  Price Is Paid Is Available Record Type  \
# 0                         CT Abdomen  535.0       1            1     HISTORY
# 2       CT Angiography with Contrast  800.0       1            1     HISTORY
# 5                           CT Chest  535.0       1            1     HISTORY
# 10      CT Angiography with Contrast  800.0       0            0     HISTORY
# 13                             HBsAg   50.0       0            0     HISTORY
# ...                              ...    ...     ...          ...         ...
# 150925                           HCV   50.0       1            1  MANAGEMENT
# 150927           CHEST X RAY LATERAL   80.0       1            1     HISTORY
# 150928                CHEST X RAY PA   80.0       1            1  MANAGEMENT
# 150929      New Patient Registration  100.0       1            0     HISTORY
# 150930  Patient Registration Renewal  100.0       1            0     HISTORY
#
#                                                   Value.1 Record Type.1  \
# 0       Known cardiac pt on follow up on atenolol 25mg...  Prescription
# 2       c/c: BACK PAIN/01 month  45yrs old female pati...  Prescription
# 5       P/E H.E.E.N.T: pink conjuctivae  and NICS LGS:...  Prescription
# 10      he is a 19 year old patient who had followup a...  Prescription
# 13      Known HTN with HHD and polycythemia pt and B.A...  Prescription
# ...                                                   ...           ...
# 150925  CBC ABO-RH ESR CXR LINK TO GENERAL SURGERY (CO...  Prescription
# 150927                                           INR 2.44  Prescription
# 150928                    Warfarin 5mg po/day for 01month  Prescription
# 150929  P: MDD + Conversion d/o Rx: Flouxetine 20mg PO...  Prescription
# 150930  GDM + LATE 2ND TMP ON  DIATERY MODIFICATION  S...  Prescription
#
#                                           Prescribed Item
# 0       {"Name":"paracetamol","Strength":"10mg","Presc...
# 2       {"PrescriptionType":"Supply","Name":"CEFTRIAXO...
# 5       {"PrescriptionType":"Supply","Name":"PLASILE 1...
# 10      {"PrescriptionType":"Supply","Name":"GLOVE ","...
# 13      {"PrescriptionType":"Medication","Name":"Olanz...
# ...                                                   ...
# 150925  {"PrescriptionType":"Supply","Name":"NORMAL SA...
# 150927  {"PrescriptionType":"Supply","Name":"VACOMYCIN...
# 150928  {"PrescriptionType":"Supply","Name":"IV CAMULA...
# 150929  {"PrescriptionType":"Supply","Name":"amoxacill...
# 150930  {"PrescriptionType":"Supply","Name":"ns","Stre...
#
# [19721 rows x 26 columns]

# %%
filtered_df.columns
# Out:
# Index(['MRN', 'Age', 'Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity',
#        'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date',
#        'Unit', 'Record', 'Value', 'Service', 'Price', 'Is Paid',
#        'Is Available', 'Record Type', 'Value.1', 'Record Type.1',
#        'Prescribed Item'],
#       dtype='object')

# %% [markdown]
# # filter out redance basde on the region
# - Urban='Addis Ababa', 'Dire Dawa', 'Mekelle', 'Bahir Dar', 'Hawassa',
#                  'Adama', 'Semera', 'Jijiga', 'Asosa', 'Gambela'
# -  if not above rular

# %%
import numpy as np

# List of urban regions
urban_regions = ['Addis Ababa', 'Dire Dawa', 'Mekelle', 'Bahir Dar', 'Hawassa', 
                 'Adama', 'Semera', 'Jijiga', 'Asosa', 'Gambela']

# Create the 'Residence' column: 'urban' if in the list of urban regions, else 'rural'
filtered_df['Residence'] = np.where(filtered_df['Region'].isin(urban_regions), 'urban', 'rural')

# Display the dataframe with the new 'Residence' column
filtered_df.head()
# Out:
# C:\Users\Daveee\AppData\Local\Temp\ipykernel_4416\3764823483.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Residence'] = np.where(filtered_df['Region'].isin(urban_regions), 'urban', 'rural')
#          MRN   Age     Sex Occupation  \
# 0   272161.0  50.0    Male        NaN
# 2   271933.0  45.0  Female        NaN
# 5   272272.0  51.0  Female        NaN
# 10  272380.0  72.0  Female        NaN
# 13  267125.0  60.0    Male        NaN
#
#                                          Region             Zone         City  \
# 0   Southern Nations, Nationalities and Peoples           Gurage      Welkite
# 2                                        Oromia  Oromia-Finfinne       BURAYU
# 5                                   Addis Ababa      Addis Ababa  Addis Ababa
# 10                             Benshangul-Gumaz            Asosa        Asosa
# 13  Southern Nations, Nationalities and Peoples           Gurage       GURAGE
#
#    SubCity   Woreda Kebel  ...  Value                       Service  Price  \
# 0      NaN  Welkite   NaN  ...     83                    CT Abdomen  535.0
# 2      NaN   BURAYU   NaN  ...     92  CT Angiography with Contrast  800.0
# 5     Yeka        1   NaN  ...  97/62                      CT Chest  535.0
# 10     NaN    Asosa   NaN  ...     78  CT Angiography with Contrast  800.0
# 13     NaN   ENDGJE   NaN  ...  95/62                         HBsAg   50.0
#
#    Is Paid Is Available Record Type  \
# 0        1            1     HISTORY
# 2        1            1     HISTORY
# 5        1            1     HISTORY
# 10       0            0     HISTORY
# 13       0            0     HISTORY
#
#                                               Value.1 Record Type.1  \
# 0   Known cardiac pt on follow up on atenolol 25mg...  Prescription
# 2   c/c: BACK PAIN/01 month  45yrs old female pati...  Prescription
# 5   P/E H.E.E.N.T: pink conjuctivae  and NICS LGS:...  Prescription
# 10  he is a 19 year old patient who had followup a...  Prescription
# 13  Known HTN with HHD and polycythemia pt and B.A...  Prescription
#
#                                       Prescribed Item  Residence
# 0   {"Name":"paracetamol","Strength":"10mg","Presc...      rural
# 2   {"PrescriptionType":"Supply","Name":"CEFTRIAXO...      rural
# 5   {"PrescriptionType":"Supply","Name":"PLASILE 1...      urban
# 10  {"PrescriptionType":"Supply","Name":"GLOVE ","...      rural
# 13  {"PrescriptionType":"Medication","Name":"Olanz...      rural
#
# [5 rows x 27 columns]

# %% [markdown]
# # form the Diagnosis filter out type of tumor

# %%
# Function to filter values
def filter_disease_classification(value):
    if pd.isna(value):
        return None
    value = value.lower()
    if 'benign' in value:
        return 'Benign'
    elif 'malignant' in value:
        return 'Malignant'
    else:
        return None

# Apply the filter function to create the 'Severity_level_classification' column
filtered_df['Tumor_Type'] = filtered_df['Diagnosis'].apply(filter_disease_classification)

# Fill NA values in 'diagnosis' with the mode of the column
mode_value = filtered_df['Tumor_Type'].mode()[0]
filtered_df['Tumor_Type'].fillna(mode_value, inplace=True)
# Out:
# C:\Users\Daveee\AppData\Local\Temp\ipykernel_4416\3135893285.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Tumor_Type'] = filtered_df['Diagnosis'].apply(filter_disease_classification)
# C:\Users\Daveee\AppData\Local\Temp\ipykernel_4416\3135893285.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Tumor_Type'].fillna(mode_value, inplace=True)

# %%
filtered_df.columns
# Out:
# Index(['MRN', 'Age', 'Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity',
#        'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date',
#        'Unit', 'Record', 'Value', 'Service', 'Price', 'Is Paid',
#        'Is Available', 'Record Type', 'Value.1', 'Record Type.1',
#        'Prescribed Item', 'Residence', 'Tumor_Type'],
#       dtype='object')

# %% [markdown]
# # from tumor type have classified as four cancer stage
# - Benign, stage1,& stage2 based on the Diagnosis and Prescribed Item
# - Malignant, stage3 & stage4 based on the Diagnosis and Prescribed Item

# %%
# Function to determine the stage based on the classification of disease
def determine_stage(classification):
    if 'Benign neoplasm' in classification:
        return 'stage1'
    elif 'Benign' in classification:
        return 'stage2'
    elif 'Malignant neoplasm' in classification:
        return 'stage3'
    else:
        return 'stage4'

# Apply the function to the 'Classification of Disease' column to create the new 'Stage' column
filtered_df['Stage'] = filtered_df['Diagnosis'].apply(determine_stage)
# Out:
# C:\Users\Daveee\AppData\Local\Temp\ipykernel_4416\180421471.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Stage'] = filtered_df['Diagnosis'].apply(determine_stage)

# %%
filtered_df.columns
# Out:
# Index(['MRN', 'Age', 'Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity',
#        'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date',
#        'Unit', 'Record', 'Value', 'Service', 'Price', 'Is Paid',
#        'Is Available', 'Record Type', 'Value.1', 'Record Type.1',
#        'Prescribed Item', 'Residence', 'Tumor_Type', 'Stage'],
#       dtype='object')

# %%
filtered_df
# Out:
#              MRN   Age     Sex Occupation  \
# 0       272161.0  50.0    Male        NaN
# 2       271933.0  45.0  Female        NaN
# 5       272272.0  51.0  Female        NaN
# 10      272380.0  72.0  Female        NaN
# 13      267125.0  60.0    Male        NaN
# ...          ...   ...     ...        ...
# 150925  193905.0  40.0  Female        NaN
# 150927  192271.0  45.0  Female        NaN
# 150928    1323.0  39.0  Female        NaN
# 150929   10222.0  21.0    Male        NaN
# 150930  160158.0  29.0  Female        NaN
#
#                                              Region             Zone  \
# 0       Southern Nations, Nationalities and Peoples           Gurage
# 2                                            Oromia  Oromia-Finfinne
# 5                                       Addis Ababa      Addis Ababa
# 10                                 Benshangul-Gumaz            Asosa
# 13      Southern Nations, Nationalities and Peoples           Gurage
# ...                                             ...              ...
# 150925                                       Oromia       East Shewa
# 150927                                  Addis Ababa      Addis Ababa
# 150928                                       Oromia  Oromia-Finfinne
# 150929                                          NaN              NaN
# 150930                                  Addis Ababa      Addis Ababa
#
#                    City  SubCity   Woreda Kebel  ...  Price Is Paid  \
# 0               Welkite      NaN  Welkite   NaN  ...  535.0       1
# 2                BURAYU      NaN   BURAYU   NaN  ...  800.0       1
# 5           Addis Ababa     Yeka        1   NaN  ...  535.0       1
# 10                Asosa      NaN    Asosa   NaN  ...  800.0       0
# 13               GURAGE      NaN   ENDGJE   NaN  ...   50.0       0
# ...                 ...      ...      ...   ...  ...    ...     ...
# 150925            Adama    Adama    Adama   NaN  ...   50.0       1
# 150927      Addis Ababa  Gullele        6   NaN  ...   80.0       1
# 150928  Oromia-Finfinne      NaN   sebeta   NaN  ...   80.0       1
# 150929              NaN   KIRKOS      NaN   NaN  ...  100.0       1
# 150930      Addis Ababa    Kolfe        3   NaN  ...  100.0       1
#
#        Is Available Record Type  \
# 0                 1     HISTORY
# 2                 1     HISTORY
# 5                 1     HISTORY
# 10                0     HISTORY
# 13                0     HISTORY
# ...             ...         ...
# 150925            1  MANAGEMENT
# 150927            1     HISTORY
# 150928            1  MANAGEMENT
# 150929            0     HISTORY
# 150930            0     HISTORY
#
#                                                   Value.1 Record Type.1  \
# 0       Known cardiac pt on follow up on atenolol 25mg...  Prescription
# 2       c/c: BACK PAIN/01 month  45yrs old female pati...  Prescription
# 5       P/E H.E.E.N.T: pink conjuctivae  and NICS LGS:...  Prescription
# 10      he is a 19 year old patient who had followup a...  Prescription
# 13      Known HTN with HHD and polycythemia pt and B.A...  Prescription
# ...                                                   ...           ...
# 150925  CBC ABO-RH ESR CXR LINK TO GENERAL SURGERY (CO...  Prescription
# 150927                                           INR 2.44  Prescription
# 150928                    Warfarin 5mg po/day for 01month  Prescription
# 150929  P: MDD + Conversion d/o Rx: Flouxetine 20mg PO...  Prescription
# 150930  GDM + LATE 2ND TMP ON  DIATERY MODIFICATION  S...  Prescription
#
#                                           Prescribed Item Residence  \
# 0       {"Name":"paracetamol","Strength":"10mg","Presc...     rural
# 2       {"PrescriptionType":"Supply","Name":"CEFTRIAXO...     rural
# 5       {"PrescriptionType":"Supply","Name":"PLASILE 1...     urban
# 10      {"PrescriptionType":"Supply","Name":"GLOVE ","...     rural
# 13      {"PrescriptionType":"Medication","Name":"Olanz...     rural
# ...                                                   ...       ...
# 150925  {"PrescriptionType":"Supply","Name":"NORMAL SA...     rural
# 150927  {"PrescriptionType":"Supply","Name":"VACOMYCIN...     urban
# 150928  {"PrescriptionType":"Supply","Name":"IV CAMULA...     rural
# 150929  {"PrescriptionType":"Supply","Name":"amoxacill...     rural
# 150930  {"PrescriptionType":"Supply","Name":"ns","Stre...     urban
#
#        Tumor_Type   Stage
# 0       Malignant  stage3
# 2       Malignant  stage3
# 5       Malignant  stage3
# 10      Malignant  stage3
# 13      Malignant  stage3
# ...           ...     ...
# 150925  Malignant  stage4
# 150927  Malignant  stage4
# 150928  Malignant  stage4
# 150929  Malignant  stage4
# 150930  Malignant  stage4
#
# [19721 rows x 29 columns]

# %%
filtered_df.to_csv('C:/Users/Daveee/Desktop/image caption model with app/Text Datasets/FilteredDatasetDiagnosis.csv', index=False)

# %% [markdown]
# # ****Phase I****
# ## Data Undestanding, Data preproesssing (Data quality Issue) and Explanetory Data analytics (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import warnings
import os
import scipy

from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
df= pd.read_csv('C:/Users/Daveee/Desktop/Tumor & Stage coding/Text Datasets/FilteredDatasetDiagnosis.csv')
df
# Out:
#             MRN   Age     Sex     Occupation  \
# 0      272161.0  50.0    Male            NaN
# 1      271933.0  45.0  Female            NaN
# 2      272272.0  51.0  Female            NaN
# 3      272380.0  72.0  Female            NaN
# 4      267125.0  60.0    Male            NaN
# ...         ...   ...     ...            ...
# 19719   10222.0  21.0    Male            NaN
# 19720  160158.0  29.0  Female            NaN
# 19721       NaN   NaN     NaN         farmer
# 19722       NaN   NaN     NaN  Self_employes
# 19723       NaN   NaN     NaN       student
#
#                                             Region             Zone  \
# 0      Southern Nations, Nationalities and Peoples           Gurage
# 1                                           Oromia  Oromia-Finfinne
# 2                                      Addis Ababa      Addis Ababa
# 3                                 Benshangul-Gumaz            Asosa
# 4      Southern Nations, Nationalities and Peoples           Gurage
# ...                                            ...              ...
# 19719                                          NaN              NaN
# 19720                                  Addis Ababa      Addis Ababa
# 19721                                          NaN              NaN
# 19722                                          NaN              NaN
# 19723                                          NaN              NaN
#
#               City SubCity   Woreda Kebel  ...  Price Is Paid Is Available  \
# 0          Welkite     NaN  Welkite   NaN  ...  535.0     1.0          1.0
# 1           BURAYU     NaN   BURAYU   NaN  ...  800.0     1.0          1.0
# 2      Addis Ababa    Yeka        1   NaN  ...  535.0     1.0          1.0
# 3            Asosa     NaN    Asosa   NaN  ...  800.0     0.0          0.0
# 4           GURAGE     NaN   ENDGJE   NaN  ...   50.0     0.0          0.0
# ...            ...     ...      ...   ...  ...    ...     ...          ...
# 19719          NaN  KIRKOS      NaN   NaN  ...  100.0     1.0          0.0
# 19720  Addis Ababa   Kolfe        3   NaN  ...  100.0     1.0          0.0
# 19721          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
# 19722          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
# 19723          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
#
#       Record Type                                            Value.1  \
# 0         HISTORY  Known cardiac pt on follow up on atenolol 25mg...
# 1         HISTORY  c/c: BACK PAIN/01 month  45yrs old female pati...
# 2         HISTORY  P/E H.E.E.N.T: pink conjuctivae  and NICS LGS:...
# 3         HISTORY  he is a 19 year old patient who had followup a...
# 4         HISTORY  Known HTN with HHD and polycythemia pt and B.A...
# ...           ...                                                ...
# 19719     HISTORY  P: MDD + Conversion d/o Rx: Flouxetine 20mg PO...
# 19720     HISTORY  GDM + LATE 2ND TMP ON  DIATERY MODIFICATION  S...
# 19721         NaN                                                NaN
# 19722         NaN                                                NaN
# 19723         NaN                                                NaN
#
#       Record Type.1                                    Prescribed Item  \
# 0      Prescription  {"Name":"paracetamol","Strength":"10mg","Presc...
# 1      Prescription  {"PrescriptionType":"Supply","Name":"CEFTRIAXO...
# 2      Prescription  {"PrescriptionType":"Supply","Name":"PLASILE 1...
# 3      Prescription  {"PrescriptionType":"Supply","Name":"GLOVE ","...
# 4      Prescription  {"PrescriptionType":"Medication","Name":"Olanz...
# ...             ...                                                ...
# 19719  Prescription  {"PrescriptionType":"Supply","Name":"amoxacill...
# 19720  Prescription  {"PrescriptionType":"Supply","Name":"ns","Stre...
# 19721           NaN                                                NaN
# 19722           NaN                                                NaN
# 19723           NaN                                                NaN
#
#       Residence Tumor_Type   Stage
# 0         rural  Malignant  stage3
# 1         rural  Malignant  stage3
# 2         urban  Malignant  stage3
# 3         rural  Malignant  stage3
# 4         rural  Malignant  stage3
# ...         ...        ...     ...
# 19719     rural  Malignant  stage4
# 19720     urban  Malignant  stage4
# 19721       NaN        NaN     NaN
# 19722       NaN        NaN     NaN
# 19723       NaN        NaN     NaN
#
# [19724 rows x 29 columns]

# %% [markdown]
# # cheecking the missing value if any by Percnetage

# %%
# Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Create a DataFrame to display the results
missing_table = pd.DataFrame({
    'Column': missing_percentage.index,
    'Missing Values (%)': missing_percentage.values
})

# Optional: Set column as index
missing_table.set_index('Column', inplace=True)

# Display the table
print(missing_table)
# Out:
#                  Missing Values (%)
# Column
# MRN                        0.015210
# Age                        0.015210
# Sex                        0.015210
# Occupation                99.979720
# Region                     4.603529
# Zone                       4.628879
# City                       6.327317
# SubCity                   33.208274
# Woreda                    13.298520
# Kebel                     89.444332
# Diagnosis                  0.015210
# Group                      0.015210
# Type                       0.015210
# Status                     0.015210
# Date                       0.015210
# Unit                       0.015210
# Record                     0.015210
# Value                      0.040560
# Service                    0.015210
# Price                      0.015210
# Is Paid                    0.015210
# Is Available               0.015210
# Record Type                0.015210
# Value.1                    0.030420
# Record Type.1              0.015210
# Prescribed Item            0.015210
# Residence                  0.015210
# Tumor_Type                 0.015210
# Stage                      0.015210

# %%
# Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Create a DataFrame to display the results
missing_table = pd.DataFrame({
    'Column': missing_percentage.index,
    'Missing Values (%)': missing_percentage.values
})

# Optional: Set column as index
missing_table.set_index('Column', inplace=True)

# Sort the table in descending order by the percentage of missing values
missing_table.sort_values(by='Missing Values (%)', ascending=False, inplace=True)

# Display the table
print(missing_table)
# Out:
#                  Missing Values (%)
# Column
# Occupation                99.979720
# Kebel                     89.444332
# SubCity                   33.208274
# Woreda                    13.298520
# City                       6.327317
# Zone                       4.628879
# Region                     4.603529
# Value                      0.040560
# Value.1                    0.030420
# Tumor_Type                 0.015210
# Price                      0.015210
# Residence                  0.015210
# Prescribed Item            0.015210
# Record Type.1              0.015210
# Record Type                0.015210
# Is Available               0.015210
# Is Paid                    0.015210
# MRN                        0.015210
# Date                       0.015210
# Service                    0.015210
# Record                     0.015210
# Unit                       0.015210
# Age                        0.015210
# Status                     0.015210
# Type                       0.015210
# Group                      0.015210
# Diagnosis                  0.015210
# Sex                        0.015210
# Stage                      0.015210

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df
# Out:
#             MRN   Age     Sex     Occupation  \
# 0      272161.0  50.0    Male            NaN
# 1      271933.0  45.0  Female            NaN
# 2      272272.0  51.0  Female            NaN
# 3      272380.0  72.0  Female            NaN
# 4      267125.0  60.0    Male            NaN
# ...         ...   ...     ...            ...
# 19719   10222.0  21.0    Male            NaN
# 19720  160158.0  29.0  Female            NaN
# 19721       NaN   NaN     NaN         farmer
# 19722       NaN   NaN     NaN  Self_employes
# 19723       NaN   NaN     NaN       student
#
#                                             Region             Zone  \
# 0      Southern Nations, Nationalities and Peoples           Gurage
# 1                                           Oromia  Oromia-Finfinne
# 2                                      Addis Ababa      Addis Ababa
# 3                                 Benshangul-Gumaz            Asosa
# 4      Southern Nations, Nationalities and Peoples           Gurage
# ...                                            ...              ...
# 19719                                          NaN              NaN
# 19720                                  Addis Ababa      Addis Ababa
# 19721                                          NaN              NaN
# 19722                                          NaN              NaN
# 19723                                          NaN              NaN
#
#               City SubCity   Woreda Kebel  ...  Price Is Paid Is Available  \
# 0          Welkite     NaN  Welkite   NaN  ...  535.0     1.0          1.0
# 1           BURAYU     NaN   BURAYU   NaN  ...  800.0     1.0          1.0
# 2      Addis Ababa    Yeka        1   NaN  ...  535.0     1.0          1.0
# 3            Asosa     NaN    Asosa   NaN  ...  800.0     0.0          0.0
# 4           GURAGE     NaN   ENDGJE   NaN  ...   50.0     0.0          0.0
# ...            ...     ...      ...   ...  ...    ...     ...          ...
# 19719          NaN  KIRKOS      NaN   NaN  ...  100.0     1.0          0.0
# 19720  Addis Ababa   Kolfe        3   NaN  ...  100.0     1.0          0.0
# 19721          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
# 19722          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
# 19723          NaN     NaN      NaN   NaN  ...    NaN     NaN          NaN
#
#       Record Type                                            Value.1  \
# 0         HISTORY  Known cardiac pt on follow up on atenolol 25mg...
# 1         HISTORY  c/c: BACK PAIN/01 month  45yrs old female pati...
# 2         HISTORY  P/E H.E.E.N.T: pink conjuctivae  and NICS LGS:...
# 3         HISTORY  he is a 19 year old patient who had followup a...
# 4         HISTORY  Known HTN with HHD and polycythemia pt and B.A...
# ...           ...                                                ...
# 19719     HISTORY  P: MDD + Conversion d/o Rx: Flouxetine 20mg PO...
# 19720     HISTORY  GDM + LATE 2ND TMP ON  DIATERY MODIFICATION  S...
# 19721         NaN                                                NaN
# 19722         NaN                                                NaN
# 19723         NaN                                                NaN
#
#       Record Type.1                                    Prescribed Item  \
# 0      Prescription  {"Name":"paracetamol","Strength":"10mg","Presc...
# 1      Prescription  {"PrescriptionType":"Supply","Name":"CEFTRIAXO...
# 2      Prescription  {"PrescriptionType":"Supply","Name":"PLASILE 1...
# 3      Prescription  {"PrescriptionType":"Supply","Name":"GLOVE ","...
# 4      Prescription  {"PrescriptionType":"Medication","Name":"Olanz...
# ...             ...                                                ...
# 19719  Prescription  {"PrescriptionType":"Supply","Name":"amoxacill...
# 19720  Prescription  {"PrescriptionType":"Supply","Name":"ns","Stre...
# 19721           NaN                                                NaN
# 19722           NaN                                                NaN
# 19723           NaN                                                NaN
#
#       Residence Tumor_Type   Stage
# 0         rural  Malignant  stage3
# 1         rural  Malignant  stage3
# 2         urban  Malignant  stage3
# 3         rural  Malignant  stage3
# 4         rural  Malignant  stage3
# ...         ...        ...     ...
# 19719     rural  Malignant  stage4
# 19720     urban  Malignant  stage4
# 19721       NaN        NaN     NaN
# 19722       NaN        NaN     NaN
# 19723       NaN        NaN     NaN
#
# [19724 rows x 29 columns]

# %% [markdown]
# ## Divide data into numeric and catagorical for further data anlasis and preprocessing accordgly

# %%
# Identify numeric columns
numeric_col = df.select_dtypes(include=['number', 'float']).columns.tolist()

# Identify categorical columns
categorical_col = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()

# Print the lists
print("Numeric columns:", numeric_col)
print("Categorical columns:", categorical_col)
# Out:
# Numeric columns: ['MRN', 'Age', 'Price', 'Is Paid', 'Is Available']
# Categorical columns: ['Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity', 'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date', 'Unit', 'Record', 'Value', 'Service', 'Record Type', 'Value.1', 'Record Type.1', 'Prescribed Item', 'Residence', 'Tumor_Type', 'Stage']

# %%
Categorical_col=['Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity', 'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date', 'Unit', 'Record', 'Value', 'Service', 'Record Type', 'Value.1', 'Record Type.1', 'Prescribed Item', 'Residence', 'Tumor_Type', 'Stage']

# %%
Numeric_col=['MRN', 'Age', 'Price', 'Is Paid', 'Is Available']

# %% [markdown]
# # filling missing for categorical dataset Using:-
# - mode
# - Bfill
# - Ffill
# - constant
# - interpolate

# %%
def fill_missing_values(df, method='mode'):
    """
    Fill missing values in categorical columns using the specified method.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to process.
    method (str): The method to fill missing values ('mode', 'ffill', 'bfill', 'constant', 'least_frequent', 'interpolate').
    
    Returns:
    pd.DataFrame: The DataFrame with missing values filled.
    """
    for column in df.select_dtypes(include=['object', 'category']).columns:
        if method == 'mode':
            mode_value = df[column].mode()[0]
            df[column].fillna(mode_value, inplace=True)
        elif method == 'ffill':
            df[column].fillna(method='ffill', inplace=True)
        elif method == 'bfill':
            df[column].fillna(method='bfill', inplace=True)
        elif method == 'constant':
            df[column].fillna('Unknown', inplace=True)
        elif method == 'least_frequent':
            least_frequent = df[column].value_counts().idxmin()
            df[column].fillna(least_frequent, inplace=True)
        elif method == 'interpolate' and df[column].dtype.name == 'category':
            # Convert to ordered categorical and interpolate
            df[column] = df[column].cat.add_categories('Missing')
            df[column].fillna('Missing', inplace=True)
            df[column] = df[column].cat.codes.replace(-1, pd.NA).interpolate().astype(int)
            df[column] = pd.Categorical.from_codes(df[column], categories=df[column].cat.categories)
    
    return df

def process_excel_file(file_path, method='mode'):
    """
    Process an Excel file to fill missing values in categorical columns.
    
    Parameters:
    file_path (str): The path to the Excel file.
    method (str): The method to fill missing values ('mode', 'ffill', 'bfill', 'constant', 'least_frequent', 'interpolate').
    
    Returns:
    pd.DataFrame: The processed DataFrame.
    """
    # # Read the Excel file
    # df = pd.read_excel(file_path)
    
    # Fill missing values
    df_filled = fill_missing_values(df, method=method)
    
    return df_filled

# Example usage:
file_path = 'path_to_your_excel_file.xlsx'
method = 'mode'  # You can change this to 'ffill', 'bfill', 'constant', 'least_frequent', or 'interpolate'

# Process the Excel file and get the filled DataFrame
filled_df = process_excel_file(file_path, method=method)

# %% [markdown]
# # filling missing for Numerical Datasets
# ### Identifies numeric columns in the DataFrame.
# #### Fills missing values using the specified method:
# - 'mean': Fills with the mean of the column.
# - 'median': Fills with the median of the column.
# - 'mode': Fills with the most frequent value in the column.
# - 'ffill': Forward fills missing values.
# - 'bfill': Backward fills missing values.
# - 'constant': Fills with a constant value (e.g., 0).
# - 'knn': Uses K-Nearest Neighbors imputation to fill missing values. The number of neighbors can be specified with n_neighbors.

# %%
import pandas as pd
from sklearn.impute import KNNImputer

def fill_missing_numeric_values(df, method='mean', n_neighbors=5):
    """
    Fill missing values in numeric columns using the specified method.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to process.
    method (str): The method to fill missing values ('mean', 'median', 'mode', 'ffill', 'bfill', 'constant', 'knn').
    n_neighbors (int): Number of neighboring samples to use for KNN imputation (used only if method='knn').
    
    Returns:
    pd.DataFrame: The DataFrame with missing values filled.
    """
    for column in df.select_dtypes(include=['number']).columns:
        if method == 'mean':
            df[column].fillna(df[column].mean(), inplace=True)
        elif method == 'median':
            df[column].fillna(df[column].median(), inplace=True)
        elif method == 'mode':
            df[column].fillna(df[column].mode()[0], inplace=True)
        elif method == 'ffill':
            df[column].fillna(method='ffill', inplace=True)
        elif method == 'bfill':
            df[column].fillna(method='bfill', inplace=True)
        elif method == 'constant':
            df[column].fillna(0, inplace=True)  # Replace 0 with any constant value you prefer
        elif method == 'knn':
            imputer = KNNImputer(n_neighbors=n_neighbors)
            df[df.select_dtypes(include=['number']).columns] = imputer.fit_transform(df.select_dtypes(include=['number']))
    
    return df

def process_excel_file(file_path, method='mean', n_neighbors=5):
    """
    Process an Excel file to fill missing values in numeric columns.
    
    Parameters:
    file_path (str): The path to the Excel file.
    method (str): The method to fill missing values ('mean', 'median', 'mode', 'ffill', 'bfill', 'constant', 'knn').
    n_neighbors (int): Number of neighboring samples to use for KNN imputation (used only if method='knn').
    
    Returns:
    pd.DataFrame: The processed DataFrame.
    """
    # # Read the Excel file
    # df = pd.read_excel(file_path)
    
    # Fill missing values in numeric columns
    df_filled = fill_missing_numeric_values(df, method=method, n_neighbors=n_neighbors)
    
    return df_filled

# Example usage:
file_path = 'path_to_your_excel_file.xlsx'
method = 'knn'  # You can change this to 'mean', 'median', 'mode', 'ffill', 'bfill', 'constant', or 'knn'
n_neighbors = 5  # Number of neighbors for KNN imputation

# Process the Excel file and get the filled DataFrame
filled_df = process_excel_file(file_path, method=method, n_neighbors=n_neighbors)

# %% [markdown]
# ## AFter Fillging Missing values

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# # Identify the outlier form numerical datasets
#  ### Visualizes outliers using three types of plots:
# - Box Plot: Helps to visualize the distribution of the data and identify outliers.
# - Histogram: Shows the frequency distribution of the data and can indicate the presence of outliers.
# - Scatter Plot: Used to visualize the relationship between two numeric columns. If there's only one numeric column, it skips this plot.

# %%
def visualize_outliers(df):
    """
    Visualize outliers in numeric columns using box plots, scatter plots, and histograms.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to process.
    
    Returns:
    None
    """
    numeric_columns = df.select_dtypes(include=['number']).columns

    for column in numeric_columns:
        plt.figure(figsize=(15, 5))

        # Box plot
        plt.subplot(1, 3, 1)
        sns.boxplot(x=df[column])
        plt.title(f'Box Plot of {column}')

        # Histogram
        plt.subplot(1, 3, 2)
        sns.histplot(df[column], kde=True)
        plt.title(f'Histogram of {column}')

        # Scatter plot (if there's another numeric column to pair with)
        if len(numeric_columns) > 1:
            plt.subplot(1, 3, 3)
            for other_column in numeric_columns:
                if other_column != column:
                    sns.scatterplot(x=df[other_column], y=df[column])
                    plt.title(f'Scatter Plot of {other_column} vs {column}')
                    break

        plt.tight_layout()
        plt.show()

def process_excel_file(file_path):
    """
    Process an Excel file to identify numeric columns and visualize outliers.
    
    Parameters:
    file_path (str): The path to the Excel file.
    
    Returns:
    pd.DataFrame: The DataFrame read from the Excel file.
    """
    # # Read the Excel file
    # df = pd.read_excel(file_path)
    
    # Visualize outliers in numeric columns
    visualize_outliers(df)
    
    return df

# Example usage:
file_path = 'path_to_your_excel_file.xlsx'

# Process the Excel file and visualize outliers
df = process_excel_file(file_path)

print("Outliers in numeric columns have been visualized.")
# Out:
# Outliers in numeric columns have been visualized.

# %% [markdown]
# ## Detects  and remove outliers using the specified method:
# - 'z_score': Uses the Z-score method to detect outliers. A Z-score above the threshold (default 3) is considered an outlier.
# - 'Inter quartel range': Uses the Interquartile Range (IQR) method to detect outliers. Values outside 1.5 times the IQR below the first quartile (Q1) or above the third quartile (Q3) are considered outliers.
# ### A. outlier datection and removale using Inter quartel range

# %%
# Specify the column for which you want to remove outliers
column_name = 'Age'  # Replace with the name of your specific column

# Calculate the IQR (Interquartile Range)
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers and create a new DataFrame without outliers
df_no_outliers = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

# Visualize the original and filtered data using a boxplot
plt.figure(figsize=(10, 6))

# Boxplot for the original data
plt.subplot(1, 2, 1)
plt.boxplot(df[column_name])
plt.title('Original Data or Data with Outlier on upper bound')

# Boxplot for the data without outliers
plt.subplot(1, 2, 2)
plt.boxplot(df_no_outliers[column_name])
plt.title('Data after remove Outliers')

plt.show()

# %% [markdown]
# ### B. Outlier detections and remove using Z-score

# %%
# Specify the column from which you want to remove outliers
column_name = 'Age'

# Calculate Z-scores for the specified column
z_scores = np.abs((df[column_name] - df[column_name].mean()) / df[column_name].std())

# Set a Z-score threshold (e.g., 3)
threshold = 1

# Identify and remove outliers
df_no_outliers = df[z_scores < threshold]

# Visualize the data before and after removing outliers using a box plot
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name} (dataframe before remove outliers)')

plt.subplot(1, 2, 2)
sns.boxplot(x=df_no_outliers[column_name])
plt.title(f'Box Plot of {column_name} (dataframe after remove outliers)')

plt.show()

# %% [markdown]
# ## Check  any data redundancy or duplication

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Check the first few rows of the DataFrame to understand its structure
# print(df.head())

# Assume the unique identifier column is named 'id' (replace with your column name)
# Count occurrences of each unique entry
counts = df['MRN'].value_counts().sort_index()

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(counts.index, counts.values, marker='o')
plt.title('Data Duplication Check')
plt.xlabel('Unique MRN')
plt.ylabel('Count of Occurrences')
plt.grid(True)
plt.show()

# %% [markdown]
# # Explanatory data analytics (EDA)
# ## A. Catagorical data analysis
# #### show distrbution credit accros the country on map
# - from Region name we extract the latitude and longitude
# - from Geopspatial data we extract shapes
# - we view the disribution of credit on contry
# - identfy which region is mostly take credit and why

# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
from tqdm import tqdm  # For progress bar when geocoding

# Step 1: Load your dataset (CSV)
# Assuming the dataset has columns 'Region' and 'Target_Class' (e.g., for cancer condition)
# df = pd.read_csv("your_dataset.csv")

# Initialize Geolocator using Nominatim
geolocator = Nominatim(user_agent="ethio-map")

# Step 2: Function to get latitude and longitude from region name
def get_lat_long(region_name):
    try:
        location = geolocator.geocode(region_name + ", Ethiopia")
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except:
        return None, None

# Step 3: Add latitude and longitude columns to the DataFrame
tqdm.pandas()  # Enable progress bar for apply function
df['Latitude'], df['Longitude'] = zip(*df['Region'].progress_apply(get_lat_long))

# Step 4: Filter rows where lat-long could not be found (optional)
df_clean = df.dropna(subset=['Latitude', 'Longitude'])

# Step 5: Create a map centered on Ethiopia
ethio_map = folium.Map(location=[9.145, 40.489673], zoom_start=5)

# Step 6: Function to map and visualize based on target class
for index, row in df_clean.iterrows():
    region = row['Region']
    lat = row['Latitude']
    lon = row['Longitude']
    target_class = row['Tumor_Type']
    
    # Define color based on target class (modify this to fit your target classes)
    if target_class == 'Malignant':
        color = 'red'
    else:
        color = 'green'  # default color if target class is unknown
    
    # Add circle marker for each region
    folium.CircleMarker(
        location=[lat, lon],
        radius=10,
        popup=f"{region}: {target_class} cases",
        color=color,
        fill=True,
        fill_color=color
    ).add_to(ethio_map)

# Step 7: Save and display the map
ethio_map.save("ethiopia_cancer_map.html")
print("Map has been saved as 'ethiopia_cancer_map.html'")
# Out:
#  12%|█▏        | 2339/19724 [20:13<2:25:55,  1.99it/s]

# %%
df['Tumor_Type'].value_counts()
# Out:
# Tumor_Type
# Malignant    19456
# Benign         268
# Name: count, dtype: int64

# %%
df['Stage'].value_counts()

# %%
df.columns
# Out:
# Index(['MRN', 'Age', 'Sex', 'Occupation', 'Region', 'Zone', 'City', 'SubCity',
#        'Woreda', 'Kebel', 'Diagnosis', 'Group', 'Type', 'Status', 'Date',
#        'Unit', 'Record', 'Value', 'Service', 'Price', 'Is Paid',
#        'Is Available', 'Record Type', 'Value.1', 'Record Type.1',
#        'Prescribed Item', 'Residence', 'Tumor_Type', 'Stage'],
#       dtype='object')

# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
from tqdm import tqdm
from IPython.display import display

# Step 1: Load your dataset (CSV)
# df = pd.read_csv("your_dataset.csv")

# Initialize Geolocator using Nominatim
geolocator = Nominatim(user_agent="ethio-map")

# Step 2: Function to get latitude and longitude from region name
def get_lat_long(region_name):
    try:
        location = geolocator.geocode(region_name + ", Ethiopia")
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except:
        return None, None

# Step 3: Add latitude and longitude columns to the DataFrame
tqdm.pandas()  # Enable progress bar for apply function
df['Latitude'], df['Longitude'] = zip(*df['Region'].progress_apply(get_lat_long))

# Step 4: Filter rows where lat-long could not be found (optional)
df_clean = df.dropna(subset=['Latitude', 'Longitude'])

# Step 5: Create a map centered on Ethiopia
ethio_map = folium.Map(location=[9.145, 40.489673], zoom_start=5)

# Step 6: Function to map and visualize based on Tumor_Type
# Assign colors for Malignant and Benign
tumor_colors = {
    'Malignant': 'red',   # Red for Malignant tumors
    'Benign': 'green'     # Green for Benign tumors
}

for index, row in df_clean.iterrows():
    region = row['Region']
    lat = row['Latitude']
    lon = row['Longitude']
    tumor_type = row['Tumor_Type']
    
    # Get the color for the tumor type
    color = tumor_colors.get(tumor_type, 'blue')  # Default color is blue if type is not found
    
    # Add circle marker for each region
    folium.CircleMarker(
        location=[lat, lon],
        radius=10,
        popup=f"{region}: {tumor_type}",
        color=color,
        fill=True,
        fill_color=color
    ).add_to(ethio_map)

# Step 7: Display the map directly
display(ethio_map._repr_html_())
